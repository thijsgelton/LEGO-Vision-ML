# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from sklearn.externals import joblib
import matplotlib.pyplot as plt
import numpy as np
import cv2
import sys
import selectivesearch
import matplotlib.patches as mpatches
from skimage.filters import gaussian

sys.path.append(r"D:\Projects\LEGO Vision\Helpers")
import helpers

# %%
img = r"D:\LEGO Vision Datasets\Detection\Natural Data_output\positive\IMG_20181105_092359.jpg"
img = helpers.image_resize(cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB), width=1024)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,15))
ax.imshow(img)
plt.show()

# %%
saliency = cv2.saliency.StaticSaliencySpectralResidual_create()
(success, saliencyMap) = saliency.computeSaliency(image)
saliencyMap = (saliencyMap * 255).astype("uint8")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4277057d382e> in <module>()
# ----> 1 saliency = cv2.cv2.saliency.StaticSaliencySpectralResidual_create()
#       2 (success, saliencyMap) = saliency.computeSaliency(image)
#       3 saliencyMap = (saliencyMap * 255).astype("uint8")
#
# AttributeError: module 'cv2.cv2' has no attribute 'saliency'
