# %%
# %matplotlib inline
print(__doc__)

import helpers

# Plot non-normalized confusion matrix
helpers.plot_confusion_matrix_with_acc_and_fbeta([0,2,1,4,2,2,1,2,3,4], [0,1,3,4,2,2,1,2,3,4], classes=['hond', 'kat', 'cavia', 'papegaai', 'zeeleeuw'],
                      title='Confusion matrix, without normalization', fbeta_beta=1.0)

helpers.plot_confusion_matrix_with_acc_and_fbeta([0,2,3,1,2,2,1,2,3,4,], [0,1,3,4,2,2,1,2,3,4], classes=['hond', 'kat', 'cavia', 'papegaai', 'zeeleeuw'], normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Automatically created module for IPython interactive environment
# Confusion matrix, without normalization
# Normalized confusion matrix
