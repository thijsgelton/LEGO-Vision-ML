# %%
# %matplotlib inline
import helpers

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import azureml
from azureml.core import Workspace, Run

# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  0.1.65

# %%
# load workspace configuration from the config.json file in the current folder.
ws = Workspace.from_config(path="../aml_config/config.json")
print(ws.name, ws.location, ws.resource_group, ws.location, sep = '\t')
# Out:
# Found the config file in: C:\Users\Thijs\Google Drive\LEGO Vision\Notebooks\aml_config\config.json
# LEGO-Vision	westeurope	LEGO-Vision	westeurope

# %%
compute_target = ws.compute_targets()["LEGO-Visiongpu"]

# %%
experiment_name = 'naive-bayes-classifier'

from azureml.core import Experiment
exp = Experiment(workspace=ws, name=experiment_name)

# %%
ds = ws.get_default_datastore()
print(ds.datastore_type, ds.account_name, ds.container_name)

ds.upload(src_dir='../classification', target_path='lego-vision-classification', overwrite=True, show_progress=True)
# Out:
# AzureFile legovision1529597820 azureml-filestore-f0102bff-6d0a-47ad-b50c-4709fd2f206a
# $AZUREML_DATAREFERENCE_0da65705ca634cf9816797fb307ff2fc

# %%
import os
script_folder = './lego-vision-classifier'
os.makedirs(script_folder, exist_ok=True)

# %%
# %%writefile $script_folder/train.py

import argparse
import os
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.externals import joblib
from sklearn.metrics import classification_report,accuracy_score, fbeta_score

from sklearn.model_selection import train_test_split
import numpy as np

from azureml.core import Run
import helpers

from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

classifiers = {'gaussian': GaussianNB(), 'bernoulli': BernoulliNB(), 'multinomial': MultinomialNB()}


# let user feed in 2 parameters, the location of the data files (from datastore), and the regularization rate of the logistic regression model
parser = argparse.ArgumentParser()
parser.add_argument('--classifier', type=str, dest='classifier', help='What Naive Bayes classifier to use. gaussian, bernoulli, multinomial')
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder mounting point')
args = parser.parse_args()

data_folder = os.path.join(args.data_folder, 'lego-vision-classification')
print('Data folder:', data_folder)

X, y = helpers.images_to_dataset(dataset_path=data_folder, to_grayscale=False, shape=(128,128), 
                                 smoothing=0.1, to_hog=True, pixels_per_cell=(8,8), cells_per_block=(8,8), orientations=9,
                                 denoising=0.2, samples=200)

X = np.array(X)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# get hold of the current run
run = Run.get_submitted_run()

print('Train a naive bayes model, classifier: ', args.classifier)
clf = classifiers.get(args.classifier)
clf.fit(X_train, y_train)

print('Predict the test set')
y_hat = clf.predict(X_test)

# calculate accuracy on the prediction
acc = accuracy_score(y_test, y_hat)
print("F-Beta with fbeta_score(y_test, y_pred, beta=0.6, 'macro')")
fbeta = fbeta_score(y_test, y_hat, beta=0.6, average='macro')

print(f"Accuracy: {acc}")
print(classification_report(y_test, y_hat))

run.log('classifier', args.classifier)
run.log('accuracy', np.float(acc))
run.log('fbeta-score', np.float(fbeta))

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=clf, filename='outputs/nb-classifier.pkl')
# Out:
# Overwriting ./lego-vision-classifier/train.py

# %%
import argparse
import os
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.externals import joblib
from sklearn.metrics import classification_report,accuracy_score, fbeta_score

from sklearn.model_selection import train_test_split
import numpy as np

from azureml.core import Run
import helpers

from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

classifiers = {'gaussian': GaussianNB(), 'bernoulli': BernoulliNB(), 'multinomial': MultinomialNB()}


# let user feed in 2 parameters, the location of the data files (from datastore), and the regularization rate of the logistic regression model
data_folder = os.path.join(r'C:\Users\Thijs\Google Drive\LEGO Vision\Notebooks', 'classification')
print('Data folder:', data_folder)

X, y = helpers.images_to_dataset(dataset_path=data_folder, to_grayscale=False, shape=(128,128), 
                                 smoothing=0.1, to_hog=True, pixels_per_cell=(8,8), cells_per_block=(8,8), orientations=9,
                                 denoising=0.2, samples=3)

X = np.array(X)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# get hold of the current run
# run = Run.get_submitted_run()

print('Train a naive bayes model, classifier: ', 'gaussian')
clf = classifiers.get('gaussian')
clf.fit(X_train, y_train)

print('Predict the test set')
y_hat = clf.predict(X_test)

# calculate accuracy on the prediction
acc = accuracy_score(y_test, y_hat)
print("F-Beta with fbeta_score(y_test, y_pred, beta=1.0, 'micro')")
fbeta = fbeta_score(y_test, y_hat, beta=0.6, average='macro')

print(f"Accuracy: {acc}")
print(classification_report(y_test, y_hat))

print(f"F-Score: {fbeta}")

# run.log('classifier', args.classifier)
# run.log('accuracy', np.float(acc))
# run.log('fbeta-score', np.float(fbeta))

# os.makedirs('outputs', exist_ok=True)
# # note file saved in the outputs folder is automatically uploaded into experiment record
# joblib.dump(value=clf, filename='outputs/nb-classifier.pkl')
# Out:
# Data folder: C:\Users\Thijs\Google Drive\LEGO Vision\Notebooks\classification
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Train a naive bayes model, classifier:  gaussian
# Predict the test set
# F-Beta with fbeta_score(y_test, y_pred, beta=1.0, 'micro')
# Accuracy: 0.14285714285714285
#                   precision    recall  f1-score   support
#
#        2458-blue       0.00      0.00      0.00         1
#      3003-yellow       0.00      0.00      0.00         0
#         3020-red       0.33      1.00      0.50         1
# 3039-trans-clear       0.00      0.00      0.00         2
#      3298-yellow       0.00      0.00      0.00         2
#         3710-red       0.00      0.00      0.00         0
#      6041-yellow       0.00      0.00      0.00         1
#
#      avg / total       0.05      0.14      0.07         7
#
# F-Score: 0.05782312925170067
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
import shutil
shutil.copy('helpers.py', script_folder)
# Out:
# './lego-vision-classifier\\helpers.py'

# %%
from azureml.train.estimator import Estimator

script_params = {
    '--data-folder': ds.as_mount(),
    '--classifier': 'gaussian'
}
print(script_folder, script_params, compute_target)
est = Estimator(source_directory=script_folder,
                script_params=script_params,
                compute_target=compute_target,
                entry_script='train.py',
                conda_packages=['scikit-learn', 'matplotlib', 'scikit-image'],
                custom_docker_base_image='microsoft/mmlspark:gpu-0.12',
                use_gpu=True)
# Out:
# ./lego-vision-classifier {'--data-folder': $AZUREML_DATAREFERENCE_workspacefilestore, '--classifier': 'gaussian'} <azureml.core.compute.batchai.BatchAiCompute object at 0x0000026772E695C0>

# %%
run = exp.submit(config=est)
run
# Out:
# Run(Experiment: naive-bayes-classifier,
# Id: naive-bayes-classifier_1538996964824,
# Type: azureml.scriptrun,
# Status: Preparing)

# %%
from azureml.train.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRun()

# %%
run.wait_for_completion(show_output=True) # specify True for a verbose log
# Out:
# RunId: naive-bayes-classifier_1538996964824
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# Logging into Docker registry: legovision6039404951.azurecr.io
# Login Succeeded
# Docker login(s) took 7.125763893127441 seconds
# Building image with name legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa
# Sending build context to Docker daemon  115.7kB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base:0.1.3
# 0.1.3: Pulling from azureml/base
# Digest: sha256:28eebd19420fba44a429ec1eb98539b770f4795111ecce2cc83600b5416783ab
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.1.3
#  ---> cafddcd9dc72
# Step 2/13 : USER root
#  ---> Running in 54d7c22bf5d8
#  ---> a6cf08fbb743
# Removing intermediate container 54d7c22bf5d8
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in 4188e0c1e6c9
#  ---> b7385a1056b8
# Removing intermediate container 4188e0c1e6c9
# Step 4/13 : WORKDIR /
#  ---> 5b84a51615f9
# Removing intermediate container 3923aed1a346
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 2ba701033ff4
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11 -c anaconda; fi
#  ---> Running in 215587d18ebe
#  ---> 929a4c8b2edf
# Removing intermediate container 215587d18ebe
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 6578c80f3056
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in 0c6014f5d02d
# Solving environment: ...working... done
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# expat-2.2.6          | 187 KB    |            |   0%
# expat-2.2.6          | 187 KB    | ########## | 100%
#
# dbus-1.13.2          | 554 KB    |            |   0%
# dbus-1.13.2          | 554 KB    | #########  |  91%
# dbus-1.13.2          | 554 KB    | ########## | 100%
#
# six-1.11.0           | 21 KB     |            |   0%
# six-1.11.0           | 21 KB     | ########## | 100%
#
# imageio-2.4.1        | 3.3 MB    |            |   0%
# imageio-2.4.1        | 3.3 MB    | #######6   |  77%
# imageio-2.4.1        | 3.3 MB    | #########4 |  94%
# imageio-2.4.1        | 3.3 MB    | ########## | 100%
#
# pillow-5.3.0         | 599 KB    |            |   0%
# pillow-5.3.0         | 599 KB    | ########5  |  85%
# pillow-5.3.0         | 599 KB    | ########## | 100%
#
# icu-58.2             | 22.5 MB   |            |   0%
# icu-58.2             | 22.5 MB   | ##5        |  25%
# icu-58.2             | 22.5 MB   | #####4     |  54%
# icu-58.2             | 22.5 MB   | #######5   |  75%
# icu-58.2             | 22.5 MB   | ########9  |  89%
# icu-58.2             | 22.5 MB   | #########9 |  99%
# icu-58.2             | 22.5 MB   | ########## | 100%
#
# tornado-5.1.1        | 663 KB    |            |   0%
# tornado-5.1.1        | 663 KB    | ########2  |  83%
# tornado-5.1.1        | 663 KB    | ########## | 100%
#
# mkl_fft-1.0.6        | 150 KB    |            |   0%
# mkl_fft-1.0.6        | 150 KB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# wheel-0.32.0         | 35 KB     |            |   0%
# wheel-0.32.0         | 35 KB     | ########## | 100%
#
# zlib-1.2.11          | 101 KB    |            |   0%
# zlib-1.2.11          | 101 KB    | ########## | 100%
#
# mkl-2019.0           | 204.4 MB  |            |   0%
# mkl-2019.0           | 204.4 MB  | 2          |   3%
# mkl-2019.0           | 204.4 MB  | 5          |   5%
# mkl-2019.0           | 204.4 MB  | 7          |   8%
# mkl-2019.0           | 204.4 MB  | #          |  10%
# mkl-2019.0           | 204.4 MB  | #3         |  14%
# mkl-2019.0           | 204.4 MB  | #6         |  17%
# mkl-2019.0           | 204.4 MB  | ##         |  20%
# mkl-2019.0           | 204.4 MB  | ##2        |  23%
# mkl-2019.0           | 204.4 MB  | ##6        |  26%
# mkl-2019.0           | 204.4 MB  | ##9        |  29%
# mkl-2019.0           | 204.4 MB  | ###2       |  32%
# mkl-2019.0           | 204.4 MB  | ###5       |  35%
# mkl-2019.0           | 204.4 MB  | ###8       |  38%
# mkl-2019.0           | 204.4 MB  | ####1      |  42%
# mkl-2019.0           | 204.4 MB  | ####5      |  45%
# mkl-2019.0           | 204.4 MB  | ####8      |  48%
# mkl-2019.0           | 204.4 MB  | #####1     |  52%
# mkl-2019.0           | 204.4 MB  | #####5     |  55%
# mkl-2019.0           | 204.4 MB  | #####8     |  58%
# mkl-2019.0           | 204.4 MB  | ######1    |  62%
# mkl-2019.0           | 204.4 MB  | ######4    |  65%
# mkl-2019.0           | 204.4 MB  | ######7    |  68%
# mkl-2019.0           | 204.4 MB  | #######1   |  71%
# mkl-2019.0           | 204.4 MB  | #######4   |  75%
# mkl-2019.0           | 204.4 MB  | #######8   |  78%
# mkl-2019.0           | 204.4 MB  | ########   |  80%
# mkl-2019.0           | 204.4 MB  | ########2  |  82%
# mkl-2019.0           | 204.4 MB  | ########3  |  83%
# mkl-2019.0           | 204.4 MB  | ########4  |  84%
# mkl-2019.0           | 204.4 MB  | ########4  |  85%
# mkl-2019.0           | 204.4 MB  | ########5  |  85%
# mkl-2019.0           | 204.4 MB  | ########5  |  85%
# mkl-2019.0           | 204.4 MB  | ########5  |  86%
# mkl-2019.0           | 204.4 MB  | ########5  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  86%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########6  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  87%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########7  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  88%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########8  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  89%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | ########9  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  90%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########  |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  91%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########1 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  92%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########2 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  93%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########3 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  94%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########4 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  95%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########5 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  96%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########6 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  97%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########7 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | #######6   |  76%
# gstreamer-1.14.0     | 3.8 MB    | #########1 |  91%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# numpy-base-1.15.2    | 4.2 MB    |            |   0%
# numpy-base-1.15.2    | 4.2 MB    | #######6   |  76%
# numpy-base-1.15.2    | 4.2 MB    | ########6  |  87%
# numpy-base-1.15.2    | 4.2 MB    | #########4 |  95%
# numpy-base-1.15.2    | 4.2 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# libxcb-1.13          | 502 KB    |            |   0%
# libxcb-1.13          | 502 KB    | ########1  |  81%
# libxcb-1.13          | 502 KB    | ########## | 100%
#
# openssl-1.0.2p       | 3.5 MB    |            |   0%
# openssl-1.0.2p       | 3.5 MB    | #######5   |  76%
# openssl-1.0.2p       | 3.5 MB    | #########  |  91%
# openssl-1.0.2p       | 3.5 MB    | ########## | 100%
#
# toolz-0.9.0          | 91 KB     |            |   0%
# toolz-0.9.0          | 91 KB     | ########## | 100%
#
# certifi-2018.8.24    | 140 KB    |            |   0%
# certifi-2018.8.24    | 140 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libtiff-4.0.9        | 567 KB    |            |   0%
# libtiff-4.0.9        | 567 KB    | #########2 |  93%
# libtiff-4.0.9        | 567 KB    | ########## | 100%
#
# libxml2-2.9.8        | 2.0 MB    |            |   0%
# libxml2-2.9.8        | 2.0 MB    | #######7   |  77%
# libxml2-2.9.8        | 2.0 MB    | #########6 |  96%
# libxml2-2.9.8        | 2.0 MB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########7  |  88%
# tk-8.6.8             | 3.1 MB    | #########6 |  97%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 5          |   6%
# qt-5.9.6             | 86.7 MB   | #3         |  14%
# qt-5.9.6             | 86.7 MB   | ##1        |  21%
# qt-5.9.6             | 86.7 MB   | ##9        |  29%
# qt-5.9.6             | 86.7 MB   | ###6       |  36%
# qt-5.9.6             | 86.7 MB   | ####3      |  43%
# qt-5.9.6             | 86.7 MB   | #####      |  51%
# qt-5.9.6             | 86.7 MB   | #####9     |  59%
# qt-5.9.6             | 86.7 MB   | ######6    |  67%
# qt-5.9.6             | 86.7 MB   | #######5   |  75%
# qt-5.9.6             | 86.7 MB   | ########2  |  82%
# qt-5.9.6             | 86.7 MB   | ########2  |  82%
# qt-5.9.6             | 86.7 MB   | ########2  |  82%
# qt-5.9.6             | 86.7 MB   | ########2  |  83%
# qt-5.9.6             | 86.7 MB   | ########2  |  83%
# qt-5.9.6             | 86.7 MB   | ########2  |  83%
# qt-5.9.6             | 86.7 MB   | ########3  |  83%
# qt-5.9.6             | 86.7 MB   | ########3  |  83%
# qt-5.9.6             | 86.7 MB   | ########3  |  83%
# qt-5.9.6             | 86.7 MB   | ########3  |  84%
# qt-5.9.6             | 86.7 MB   | ########3  |  84%
# qt-5.9.6             | 86.7 MB   | ########3  |  84%
# qt-5.9.6             | 86.7 MB   | ########4  |  84%
# qt-5.9.6             | 86.7 MB   | ########4  |  84%
# qt-5.9.6             | 86.7 MB   | ########4  |  84%
# qt-5.9.6             | 86.7 MB   | ########4  |  85%
# qt-5.9.6             | 86.7 MB   | ########4  |  85%
# qt-5.9.6             | 86.7 MB   | ########4  |  85%
# qt-5.9.6             | 86.7 MB   | ########4  |  85%
# qt-5.9.6             | 86.7 MB   | ########5  |  85%
# qt-5.9.6             | 86.7 MB   | ########5  |  85%
# qt-5.9.6             | 86.7 MB   | ########5  |  85%
# qt-5.9.6             | 86.7 MB   | ########5  |  86%
# qt-5.9.6             | 86.7 MB   | ########5  |  86%
# qt-5.9.6             | 86.7 MB   | ########6  |  86%
# qt-5.9.6             | 86.7 MB   | ########6  |  86%
# qt-5.9.6             | 86.7 MB   | ########6  |  86%
# qt-5.9.6             | 86.7 MB   | ########6  |  87%
# qt-5.9.6             | 86.7 MB   | ########6  |  87%
# qt-5.9.6             | 86.7 MB   | ########6  |  87%
# qt-5.9.6             | 86.7 MB   | ########7  |  87%
# qt-5.9.6             | 86.7 MB   | ########7  |  87%
# qt-5.9.6             | 86.7 MB   | ########7  |  88%
# qt-5.9.6             | 86.7 MB   | ########7  |  88%
# qt-5.9.6             | 86.7 MB   | ########7  |  88%
# qt-5.9.6             | 86.7 MB   | ########8  |  88%
# qt-5.9.6             | 86.7 MB   | ########8  |  88%
# qt-5.9.6             | 86.7 MB   | ########8  |  88%
# qt-5.9.6             | 86.7 MB   | ########8  |  89%
# qt-5.9.6             | 86.7 MB   | ########8  |  89%
# qt-5.9.6             | 86.7 MB   | ########9  |  89%
# qt-5.9.6             | 86.7 MB   | ########9  |  89%
# qt-5.9.6             | 86.7 MB   | ########9  |  89%
# qt-5.9.6             | 86.7 MB   | ########9  |  90%
# qt-5.9.6             | 86.7 MB   | ########9  |  90%
# qt-5.9.6             | 86.7 MB   | ########9  |  90%
# qt-5.9.6             | 86.7 MB   | #########  |  90%
# qt-5.9.6             | 86.7 MB   | #########  |  90%
# qt-5.9.6             | 86.7 MB   | #########  |  90%
# qt-5.9.6             | 86.7 MB   | #########  |  91%
# qt-5.9.6             | 86.7 MB   | #########  |  91%
# qt-5.9.6             | 86.7 MB   | #########  |  91%
# qt-5.9.6             | 86.7 MB   | #########1 |  91%
# qt-5.9.6             | 86.7 MB   | #########1 |  91%
# qt-5.9.6             | 86.7 MB   | #########1 |  92%
# qt-5.9.6             | 86.7 MB   | #########1 |  92%
# qt-5.9.6             | 86.7 MB   | #########1 |  92%
# qt-5.9.6             | 86.7 MB   | #########1 |  92%
# qt-5.9.6             | 86.7 MB   | #########2 |  92%
# qt-5.9.6             | 86.7 MB   | #########2 |  92%
# qt-5.9.6             | 86.7 MB   | #########2 |  92%
# qt-5.9.6             | 86.7 MB   | #########2 |  93%
# qt-5.9.6             | 86.7 MB   | #########2 |  93%
# qt-5.9.6             | 86.7 MB   | #########2 |  93%
# qt-5.9.6             | 86.7 MB   | #########3 |  93%
# qt-5.9.6             | 86.7 MB   | #########3 |  93%
# qt-5.9.6             | 86.7 MB   | #########3 |  93%
# qt-5.9.6             | 86.7 MB   | #########3 |  94%
# qt-5.9.6             | 86.7 MB   | #########3 |  94%
# qt-5.9.6             | 86.7 MB   | #########3 |  94%
# qt-5.9.6             | 86.7 MB   | #########4 |  94%
# qt-5.9.6             | 86.7 MB   | #########4 |  94%
# qt-5.9.6             | 86.7 MB   | #########4 |  94%
# qt-5.9.6             | 86.7 MB   | #########4 |  95%
# qt-5.9.6             | 86.7 MB   | #########4 |  95%
# qt-5.9.6             | 86.7 MB   | #########4 |  95%
# qt-5.9.6             | 86.7 MB   | #########5 |  95%
# qt-5.9.6             | 86.7 MB   | #########5 |  95%
# qt-5.9.6             | 86.7 MB   | #########5 |  95%
# qt-5.9.6             | 86.7 MB   | #########5 |  96%
# qt-5.9.6             | 86.7 MB   | #########5 |  96%
# qt-5.9.6             | 86.7 MB   | #########5 |  96%
# qt-5.9.6             | 86.7 MB   | #########6 |  96%
# qt-5.9.6             | 86.7 MB   | #########6 |  96%
# qt-5.9.6             | 86.7 MB   | #########6 |  96%
# qt-5.9.6             | 86.7 MB   | #########6 |  97%
# qt-5.9.6             | 86.7 MB   | #########6 |  97%
# qt-5.9.6             | 86.7 MB   | #########6 |  97%
# qt-5.9.6             | 86.7 MB   | #########7 |  97%
# qt-5.9.6             | 86.7 MB   | #########7 |  97%
# qt-5.9.6             | 86.7 MB   | #########7 |  97%
# qt-5.9.6             | 86.7 MB   | #########7 |  98%
# qt-5.9.6             | 86.7 MB   | #########7 |  98%
# qt-5.9.6             | 86.7 MB   | #########7 |  98%
# qt-5.9.6             | 86.7 MB   | #########8 |  98%
# qt-5.9.6             | 86.7 MB   | #########8 |  98%
# qt-5.9.6             | 86.7 MB   | #########8 |  98%
# qt-5.9.6             | 86.7 MB   | #########8 |  99%
# qt-5.9.6             | 86.7 MB   | #########8 |  99%
# qt-5.9.6             | 86.7 MB   | #########8 |  99%
# qt-5.9.6             | 86.7 MB   | #########9 |  99%
# qt-5.9.6             | 86.7 MB   | #########9 |  99%
# qt-5.9.6             | 86.7 MB   | #########9 |  99%
# qt-5.9.6             | 86.7 MB   | #########9 | 100%
# qt-5.9.6             | 86.7 MB   | #########9 | 100%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# scipy-1.1.0          | 18.0 MB   |            |   0%
# scipy-1.1.0          | 18.0 MB   | ##6        |  26%
# scipy-1.1.0          | 18.0 MB   | ######6    |  67%
# scipy-1.1.0          | 18.0 MB   | ########4  |  84%
# scipy-1.1.0          | 18.0 MB   | #########6 |  97%
# scipy-1.1.0          | 18.0 MB   | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########1  |  81%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# kiwisolver-1.0.1     | 83 KB     |            |   0%
# kiwisolver-1.0.1     | 83 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##1        |  22%
# python-3.6.2         | 27.0 MB   | ####4      |  44%
# python-3.6.2         | 27.0 MB   | ######6    |  67%
# python-3.6.2         | 27.0 MB   | ########1  |  82%
# python-3.6.2         | 27.0 MB   | #########2 |  92%
# python-3.6.2         | 27.0 MB   | #########9 | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #####3     |  54%
# gst-plugins-base-1.1 | 6.3 MB    | #######5   |  75%
# gst-plugins-base-1.1 | 6.3 MB    | #########1 |  92%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########1  |  82%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# dask-core-0.19.2     | 1.1 MB    |            |   0%
# dask-core-0.19.2     | 1.1 MB    | #######9   |  80%
# dask-core-0.19.2     | 1.1 MB    | #########7 |  98%
# dask-core-0.19.2     | 1.1 MB    | ########## | 100%
#
# intel-openmp-2019.0  | 721 KB    |            |   0%
# intel-openmp-2019.0  | 721 KB    | ########6  |  87%
# intel-openmp-2019.0  | 721 KB    | ########## | 100%
#
# pywavelets-1.0.1     | 4.4 MB    |            |   0%
# pywavelets-1.0.1     | 4.4 MB    | #######6   |  77%
# pywavelets-1.0.1     | 4.4 MB    | #########1 |  91%
# pywavelets-1.0.1     | 4.4 MB    | ########## | 100%
#
# cloudpickle-0.5.6    | 26 KB     |            |   0%
# cloudpickle-0.5.6    | 26 KB     | ########## | 100%
#
# freetype-2.9.1       | 822 KB    |            |   0%
# freetype-2.9.1       | 822 KB    | ########3  |  83%
# freetype-2.9.1       | 822 KB    | ########## | 100%
#
# mkl_random-1.0.1     | 373 KB    |            |   0%
# mkl_random-1.0.1     | 373 KB    | #########6 |  97%
# mkl_random-1.0.1     | 373 KB    | ########## | 100%
#
# matplotlib-3.0.0     | 6.8 MB    |            |   0%
# matplotlib-3.0.0     | 6.8 MB    | ######6    |  67%
# matplotlib-3.0.0     | 6.8 MB    | ########6  |  87%
# matplotlib-3.0.0     | 6.8 MB    | ########## | 100%
#
# decorator-4.3.0      | 15 KB     |            |   0%
# decorator-4.3.0      | 15 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | #######5   |  76%
# glib-2.56.2          | 5.0 MB    | ########5  |  85%
# glib-2.56.2          | 5.0 MB    | #########2 |  92%
# glib-2.56.2          | 5.0 MB    | #########7 |  97%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# networkx-2.2         | 2.0 MB    |            |   0%
# networkx-2.2         | 2.0 MB    | #######7   |  77%
# networkx-2.2         | 2.0 MB    | ########9  |  89%
# networkx-2.2         | 2.0 MB    | #########8 |  98%
# networkx-2.2         | 2.0 MB    | ########## | 100%
#
# setuptools-40.4.3    | 555 KB    |            |   0%
# setuptools-40.4.3    | 555 KB    | ########4  |  84%
# setuptools-40.4.3    | 555 KB    | ########## | 100%
#
# scikit-image-0.14.0  | 24.1 MB   |            |   0%
# scikit-image-0.14.0  | 24.1 MB   | ##         |  21%
# scikit-image-0.14.0  | 24.1 MB   | ####8      |  49%
# scikit-image-0.14.0  | 24.1 MB   | #######5   |  75%
# scikit-image-0.14.0  | 24.1 MB   | #########1 |  92%
# scikit-image-0.14.0  | 24.1 MB   | ########## | 100%
#
# scikit-learn-0.20.0  | 5.8 MB    |            |   0%
# scikit-learn-0.20.0  | 5.8 MB    | #######5   |  75%
# scikit-learn-0.20.0  | 5.8 MB    | #########7 |  97%
# scikit-learn-0.20.0  | 5.8 MB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# numpy-1.15.2         | 48 KB     |            |   0%
# numpy-1.15.2         | 48 KB     | ########## | 100%
#
# sip-4.19.8           | 290 KB    |            |   0%
# sip-4.19.8           | 290 KB    | ########## | 100%
#
# pytz-2018.5          | 232 KB    |            |   0%
# pytz-2018.5          | 232 KB    | ########9  |  90%
# pytz-2018.5          | 232 KB    | ########## | 100%
#
# pip-10.0.1           | 1.8 MB    |            |   0%
# pip-10.0.1           | 1.8 MB    | #######7   |  78%
# pip-10.0.1           | 1.8 MB    | ########9  |  90%
# pip-10.0.1           | 1.8 MB    | #########9 | 100%
# pip-10.0.1           | 1.8 MB    | ########## | 100%
#
# python-dateutil-2.7. | 260 KB    |            |   0%
# python-dateutil-2.7. | 260 KB    | ########## | 100%
#
# pcre-8.42            | 251 KB    |            |   0%
# pcre-8.42            | 251 KB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########  |  91%
# ncurses-6.0          | 920 KB    | #########9 |  99%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######6   |  77%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #########9 | 100%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | #######9   |  80%
# sqlite-3.23.1        | 1.5 MB    | #########9 | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | #######5   |  75%
# pyqt-5.9.2           | 5.6 MB    | #########8 |  98%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# pyparsing-2.2.1      | 96 KB     |            |   0%
# pyparsing-2.2.1      | 96 KB     | ########## | 100%
#
# libpng-1.6.34        | 334 KB    |            |   0%
# libpng-1.6.34        | 334 KB    | ########## | 100%
#
# jpeg-9b              | 248 KB    |            |   0%
# jpeg-9b              | 248 KB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | #######5   |  75%
# libgcc-ng-8.2.0      | 7.6 MB    | #########7 |  97%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# ca-certificates-2018 | 124 KB    |            |   0%
# ca-certificates-2018 | 124 KB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults (from -r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6c/4e/43fd7a7db35dd7b96f981f7abf38201be27ec414d79e6276428472466c9b/azureml_defaults-0.1.65-py2.py3-none-any.whl
# Collecting applicationinsights>=0.11.0 (from azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting azureml-core==0.1.65 (from azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/45/ed82e8caeb1083ebb1c0341ee483f999b13d61b3aef32f2ca99cc0ed3abf/azureml_core-0.1.65-py2.py3-none-any.whl (772kB)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d8/92/5411e055a0dc070527121480c3c7a941d3e1302b9866fe6db3af0bde9942/azure_mgmt_storage-3.0.0-py2.py3-none-any.whl (682kB)
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/dd/26/45de0cb737aeeeb2fa56cf12ab0042ba64dafd24bcc50bf8c8cdf913a1a6/azure_storage_blob-1.3.1-py2.py3-none-any.whl (77kB)
# Collecting ndg-httpsclient (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1)) (1.11.0)
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b1/e9/0a11f4feefb9c4c2f7e30d4d448e15b32df3adabe370be70aaf4278fbb52/azure_storage_nspkg-3.0.0-py2.py3-none-any.whl
# Collecting SecretStorage<3.0.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting msrest>=0.5.1 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ad/2a/37b2481fa1a7cd727c07d20cbcb0a3f9bf9dd994930f44dd9770df15c28d/msrest-0.5.5-py2.py3-none-any.whl (47kB)
# Collecting azure-cli-core>=2.0.38 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e5/2c/1f1ad5fb40473d4e51041fa7b406d6cd1f5f52f14ad9fe2793a09af2770d/azure_cli_core-2.0.46-py2.py3-none-any.whl (98kB)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/89/0a/29f7e2914033e2536026b8f0d7f8deb1edda68c9a93ce4757b2b1e39568b/azure_graphrbac-0.40.0-py2.py3-none-any.whl (63kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/59/32/92cade62c645756a83598edf56289e9b19aae5370642a7ce690cd06bc72f/cryptography-2.3.1-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1)) (2.7.3)
# Collecting jsonpickle (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ca/ce/97404d5aeb58e6155c216825c81b50f6eca8a5345c582317ae48391878f8/jsonpickle-1.0-py2.py3-none-any.whl
# Collecting contextlib2 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ac/d3/055ce7ad06459a415ff9ca210e04c6cbb51bd6564815b7c8ac34bf5a1c39/azure_common-1.1.16-py2.py3-none-any.whl
# Requirement already satisfied: pytz in /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1)) (2018.5)
# Collecting docker (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/06/0b/ce97eb31058eddaef316973b8299b737ebab0bcb5798fd5a3225d53b4455/docker-3.5.0-py2.py3-none-any.whl (125kB)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7b/18/03872177864b7ce4aa0302eae5726e8cb66dbb4f30a3408ed27a6639407f/azure_storage_common-1.3.0-py2.py3-none-any.whl (48kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f1/70/642eb54b3f33b90c47acdb777a5f9613ff7904abf15216cb4a164f586160/azure_cli_profile-2.1.1-py2.py3-none-any.whl
# Collecting requests>=2.19.1 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/65/47/7e02164a2a3db50ed6d8a6ab1d6d60b69c4c3fdf57a284257925dfc12bda/requests-2.19.1-py2.py3-none-any.whl (91kB)
# Collecting backports.tempfile (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6f/17/55b974603c16be89c7a7c16bac57b7bce48527bf1bebc3f116f7215176e6/azure_mgmt_authorization-0.50.0-py2.py3-none-any.whl (81kB)
# Collecting pathspec (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2b/26/c0cb69dfac2e5b7125db034045b8bcf937cf1e8d3df2009a87c33d0959f5/azure_mgmt_resource-2.0.0-py2.py3-none-any.whl (698kB)
# Collecting urllib3>=1.23 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/94/fd/63fc079c43a759784f83e9fc22ccc693a1e8bf4c733fc90036acf109c7e7/azure_mgmt_containerregistry-2.2.0-py2.py3-none-any.whl (475kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Collecting msrestazure>=0.4.33 (from azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a4/48/cfa54772365b4d0b8f3e7af16354db768b0317b3273265b37c14f71b705b/msrestazure-0.5.0-py2.py3-none-any.whl
# Collecting PyOpenSSL (from ndg-httpsclient->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d1/a1/7790cc85db38daa874f6a2e6308131b9953feb1367f2ae2d1123bb93a9f5/pyasn1-0.4.4-py2.py3-none-any.whl (72kB)
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1)) (2018.8.24)
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting adal>=1.0.2 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/15/2b/8f674c2a20bb2a55f8f1c8fb7a458c9b513409b2cfc42f73e4cbc1ee757e/adal-1.1.0-py2.py3-none-any.whl (51kB)
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: pip in /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1)) (10.0.1)
# Collecting pyyaml~=3.13 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
# Collecting knack==0.4.3 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/77/3d/b83a9fe885b1dd3f33888f9d8875a1b340b8a03daba05c573af99b069f5f/knack-0.4.3-py2.py3-none-any.whl (48kB)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting pygments (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/02/ee/b6e02dc6529e82b75bb06823ff7d005b141037cb1416b10c6f00fc419dca/Pygments-2.2.0-py2.py3-none-any.whl (841kB)
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==0.1.65->azureml-defaults->-r /azureml-setup/condaenv.08a7s5_x.requirements.txt (line 1))
# ...
#   Stored in directory: /root/.cache/pip/wheels/ef/f6/18/ad300e691236a3408a99edc750484b56e8d6b11b2c38eacb10
#   Running setup.py bdist_wheel for tabulate: started
#   Running setup.py bdist_wheel for tabulate: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/2a/85/33/2f6da85d5f10614cbe5a625eab3b3aebfdf43e7b857f25f829
#   Running setup.py bdist_wheel for pycparser: started
#   Running setup.py bdist_wheel for pycparser: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built SecretStorage pathspec pyyaml antlr4-python3-runtime tabulate pycparser
# mkl-random 1.0.1 requires cython, which is not installed.
# Installing collected packages: applicationinsights, idna, chardet, urllib3, requests, asn1crypto, pycparser, cffi, cryptography, PyJWT, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-storage, azure-nspkg, azure-storage-nspkg, azure-storage-common, azure-storage-blob, PyOpenSSL, pyasn1, ndg-httpsclient, SecretStorage, azure-cli-nspkg, portalocker, azure-cli-telemetry, pyyaml, jmespath, argcomplete, tabulate, colorama, pygments, knack, wheel, pynacl, bcrypt, paramiko, azure-mgmt-nspkg, azure-mgmt-resource, humanfriendly, antlr4-python3-runtime, azure-cli-core, azure-graphrbac, jsonpickle, contextlib2, docker-pycreds, websocket-client, docker, azure-cli-command-modules-nspkg, azure-cli-profile, backports.weakref, backports.tempfile, azure-mgmt-authorization, pathspec, azure-mgmt-keyvault, azure-mgmt-containerregistry, ruamel.yaml, azureml-core, azureml-defaults
#   Found existing installation: wheel 0.32.0
#     Uninstalling wheel-0.32.0:
#       Successfully uninstalled wheel-0.32.0
# Successfully installed PyJWT-1.6.4 PyOpenSSL-18.0.0 SecretStorage-2.3.1 adal-1.1.0 antlr4-python3-runtime-4.7.1 applicationinsights-0.11.7 argcomplete-1.9.4 asn1crypto-0.24.0 azure-cli-command-modules-nspkg-2.0.2 azure-cli-core-2.0.46 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.1 azure-cli-telemetry-1.0.0 azure-common-1.1.16 azure-graphrbac-0.40.0 azure-mgmt-authorization-0.50.0 azure-mgmt-containerregistry-2.2.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.0.0 azure-mgmt-storage-3.0.0 azure-nspkg-3.0.2 azure-storage-blob-1.3.1 azure-storage-common-1.3.0 azure-storage-nspkg-3.0.0 azureml-core-0.1.65 azureml-defaults-0.1.65 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.4 cffi-1.11.5 chardet-3.0.4 colorama-0.3.9 contextlib2-0.5.5 cryptography-2.3.1 docker-3.5.0 docker-pycreds-0.3.0 humanfriendly-4.16.1 idna-2.7 isodate-0.6.0 jmespath-0.9.3 jsonpickle-1.0 knack-0.4.3 msrest-0.5.5 msrestazure-0.5.0 ndg-httpsclient-0.5.1 oauthlib-2.1.0 paramiko-2.4.2 pathspec-0.5.9 portalocker-1.2.1 pyasn1-0.4.4 pycparser-2.19 pygments-2.2.0 pynacl-1.3.0 pyyaml-3.13 requests-2.19.1 requests-oauthlib-1.0.0 ruamel.yaml-0.15.51 tabulate-0.8.2 urllib3-1.23 websocket-client-0.53.0 wheel-0.30.0
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
#  ---> 5660e11ec1d3
# Removing intermediate container 0c6014f5d02d
# Step 9/13 : ENV PATH /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/bin:$PATH
#  ---> Running in 302513bab487
#  ---> 5878a7335c71
# Removing intermediate container 302513bab487
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib:$LD_LIBRARY_PATH
#  ---> Running in 61120d5e09ea
#  ---> 9f76c0780b62
# Removing intermediate container 61120d5e09ea
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 0664fc83312c
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12" "--conf" "spark.app.name=Azure ML Experiment" "--conf" "spark.yarn.maxAppAttempts=1" "--driver-java-options" "-Dlog4j.configuration=file:./azureml-setup/log4j.properties" "--conf" "spark.eventLog.enabled=true" "--conf" "spark.eventLog.dir=./azureml-logs" /azureml-setup/spark_cache.py'; fi
#  ---> Running in 6beb77679746
#  ---> 89da852aa424
# Removing intermediate container 6beb77679746
# Step 13/13 : CMD bash
#  ---> Running in 99cb50d8c09d
#  ---> 84bc4f29a816
# Removing intermediate container 99cb50d8c09d
# Successfully built 84bc4f29a816
# Successfully tagged legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa:latest
# Removing any dangling images
# Docker build took 596.4372408390045 seconds
# Logging into acr legovision6039404951.azurecr.io to do docker push
# Login Succeeded
# Pushing image azureml/azureml_a044629af4142394c675ebee3904b4aa to acr legovision6039404951.azurecr.io
# The push refers to a repository [legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa]
# 6dc6839b01c8: Preparing
# bfbc4f75a877: Preparing
# e44f0e49e1ab: Preparing
# bffc8725c56d: Preparing
# 737abe77b468: Preparing
# f41953166959: Preparing
# 392a009de2b3: Preparing
# 1db0da3b3d01: Preparing
# e46e9e8b1cbf: Preparing
# 75b79e19929c: Preparing
# 4775b2f378bb: Preparing
# 883eafdbe580: Preparing
# 19d043c86cbc: Preparing
# 8823818c4748: Preparing
# f41953166959: Waiting
# 392a009de2b3: Waiting
# 1db0da3b3d01: Waiting
# e46e9e8b1cbf: Waiting
# 75b79e19929c: Waiting
# 4775b2f378bb: Waiting
# 19d043c86cbc: Waiting
# 8823818c4748: Waiting
# 883eafdbe580: Waiting
# 6dc6839b01c8: Pushed
# bffc8725c56d: Pushed
# 737abe77b468: Pushed
# e44f0e49e1ab: Pushed
# e46e9e8b1cbf: Pushed
# 75b79e19929c: Pushed
# 4775b2f378bb: Pushed
# 883eafdbe580: Pushed
# 19d043c86cbc: Pushed
# f41953166959: Pushed
# 1db0da3b3d01: Pushed
# 8823818c4748: Pushed
# 392a009de2b3: Pushed
# bfbc4f75a877: Pushed
# latest: digest: sha256:d26a0709f760001135818ef5fa46466f5441c7e88a5d1436b9d96c2d70a2bc00 size: 3247
# Removing login credentials for legovision6039404951.azurecr.io
# Docker push took 592.3969011306763 seconds
# Not logged in to legovision6039404951.azurecr.io
# Docker logout(s) took 0.07497191429138184 seconds
# Removing image with name legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa
# Untagged: legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa:latest
# Untagged: legovision6039404951.azurecr.io/azureml/azureml_a044629af4142394c675ebee3904b4aa@sha256:d26a0709f760001135818ef5fa46466f5441c7e88a5d1436b9d96c2d70a2bc00
# Deleted: sha256:84bc4f29a816755bfd0c37b0a1fb80a773d4c2bc025049d199a773400a378453
# Deleted: sha256:89da852aa42455e341cdcd519e54c1b8ebac8c9ea16924c7a6b827c7c1f52cf9
# Deleted: sha256:0664fc83312c9854379f8a15b66067764ffb49e9636c4a5fad2409eb487811f6
# Deleted: sha256:b18c518c76dbaf4b89ee48194b040838e965bcb0cd72008f9c14fd647ae52c4a
# Deleted: sha256:9f76c0780b620fe9ac4d6ddc1b66c68310b919b14d763302347b58a656457e14
# Deleted: sha256:5878a7335c7128da96f01dc6efb1847e94d3eb791744e9454125a5dc39872155
# Deleted: sha256:5660e11ec1d3dddc6669981ea78cf9a2d11daa1d61c9ebc32c3eac6e94b43c86
# Deleted: sha256:d8d9f95bb3a6c8d5e98edc5a3c801c87bf320a44574cabe4aef0f05aaa2b5374
# Deleted: sha256:6578c80f30564d75d8c0a443d4550802139d73166d7ae1e9fabcbe6ba374d6ae
# Deleted: sha256:d38fbd47a96ae240f9b96ce1d63fa42ff3bbf643ecaacdade4660d84a5ed808a
# Deleted: sha256:929a4c8b2edfd49920a9232bbef6ede956a1c024bc77cbc0cd204a83352f0bf0
# Deleted: sha256:2ba701033ff441f8f0538d1811b5ca2eaf8c4bc2da01408116b405a2c1c99410
# Deleted: sha256:db2e39d4fefdb4fcdd7aefab0d35f2254993fbc6e5f73d8a8797dc4388b8b9c5
# Deleted: sha256:5b84a51615f9b43b06030651cd1f3ebab47e9478c85cd1367400a9fc8191efb7
# Deleted: sha256:b7385a1056b8635e8fc0522827ac7ca09f0678d0e61d503f6b12f48c6e19ab11
# Deleted: sha256:19d15b1e9ef9974d324fc229a816c37f0c7a310c2c9203844940b5efaaf6c85c
# Deleted: sha256:a6cf08fbb74382a32f38584aca649a5c736eb04a770dc4aa418a76989ec3778a
# Total task took 1205.4925186634064 secs
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Streaming log file azureml-logs/60_control_log.txt
# Streaming log file azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# Data folder: /mnt/batch/tasks/shared/LS_root/jobs/lego-visiongpu3fe34817d/azureml/naive-bayes-classifier_1538996964824/mounts/workspacefilestore/lego-vision-classification
# /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/skimage/restoration/_denoise.py:226: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   g[slices_g] = np.diff(out, axis=ax)
# /azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/skimage/restoration/_denoise.py:212: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   d[slices_d] += p[slices_p]
# Train a naive bayes model, classifier:  gaussian
# Predict the test set
# F-Beta with fbeta_score(y_test, y_pred, beta=0.0, 'micro')
#
#
# The experiment failed. Finalizing run...
# Logging experiment finalizing status in history service
# Traceback (most recent call last):
#   File "azureml-setup/context_manager_injector.py", line 70, in execute_with_context
#     runpy.run_path(sys.argv[0], globals(), run_name="__main__")
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "train.py", line 50, in <module>
#     fbeta = fbeta_score(y_test, y_hat, beta=0.0, average='micro')
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/sklearn/metrics/classification.py", line 834, in fbeta_score
#     sample_weight=sample_weight)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/sklearn/metrics/classification.py", line 1029, in precision_recall_fscore_support
#     raise ValueError("beta should be >0 in the F-beta score")
# ValueError: beta should be >0 in the F-beta score
#
# Traceback (most recent call last):
#   File "azureml-setup/context_manager_injector.py", line 126, in <module>
#     execute_with_context(cm_objects, options.invocation)
#   File "azureml-setup/context_manager_injector.py", line 70, in execute_with_context
#     runpy.run_path(sys.argv[0], globals(), run_name="__main__")
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "train.py", line 50, in <module>
#     fbeta = fbeta_score(y_test, y_hat, beta=0.0, average='micro')
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/sklearn/metrics/classification.py", line 834, in fbeta_score
#     sample_weight=sample_weight)
#   File "/azureml-envs/azureml_ae9aea3e99908aa5a66ce1772781b88a/lib/python3.6/site-packages/sklearn/metrics/classification.py", line 1029, in precision_recall_fscore_support
#     raise ValueError("beta should be >0 in the F-beta score")
# ValueError: beta should be >0 in the F-beta score
#
# Execution Summary
# =================
# RunId: naive-bayes-classifier_1538996964824
# {'runId': 'naive-bayes-classifier_1538996964824',
#  'target': 'LEGO-Visiongpu',
#  'status': 'Failed',
#  'startTimeUtc': '2018-10-08T11:30:28.565085Z',
#  'endTimeUtc': '2018-10-08T11:44:08.808267Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': 'e0df826c-273b-4d68-9b94-e49ec19b3efa'},
#  'runDefinition': {'Script': 'train.py',
#   'Arguments': ['--data-folder',
#    '$AZUREML_DATAREFERENCE_workspacefilestore',
#    '--classifier',
#    'gaussian'],
#   'Framework': 0,
#   'Target': 'LEGO-Visiongpu',
#   'DataReferences': {'workspacefilestore': {'DataStoreName': 'workspacefilestore',
#     'Mode': 'Mount',
#     'PathOnDataStore': None,
#     'PathOnCompute': None,
#     'Overwrite': False}},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults']},
#       'scikit-learn',
#       'matplotlib',
#       'scikit-image']},
#     'CondaDependenciesFile': None},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.1.3',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'GpuSupport': False,
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 1},
#   'Tensorflow': {'WorkerCount': 1, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 1, 'MemoryGb': 4},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://legovision1529597820.blob.core.windows.net/azureml/ExperimentRun/naive-bayes-classifier_1538996964824/azureml-logs/20_image_build_log.txt?sv=2017-04-17&sr=b&sig=k%2BJOZAPEYvyhNhdEJvUn7syvn6UljIThWhj%2FomgOz80%3D&st=2018-10-08T11%3A34%3A10Z&se=2018-10-08T19%3A44%3A10Z&sp=r',
#   'azureml-logs/60_control_log.txt': 'https://legovision1529597820.blob.core.windows.net/azureml/ExperimentRun/naive-bayes-classifier_1538996964824/azureml-logs/60_control_log.txt?sv=2017-04-17&sr=b&sig=WajcmPXtxA60zeGoW6%2FgTF%2FdJLgXB65cMc%2FJA0KUkQU%3D&st=2018-10-08T11%3A34%3A10Z&se=2018-10-08T19%3A44%3A10Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://legovision1529597820.blob.core.windows.net/azureml/ExperimentRun/naive-bayes-classifier_1538996964824/azureml-logs/80_driver_log.txt?sv=2017-04-17&sr=b&sig=hwKjhLdWkEJiYr4tvmWZbCGwyO41wqdg5XtQuWZb0HU%3D&st=2018-10-08T11%3A34%3A10Z&se=2018-10-08T19%3A44%3A10Z&sp=r',
#   'azureml-logs/azureml.log': 'https://legovision1529597820.blob.core.windows.net/azureml/ExperimentRun/naive-bayes-classifier_1538996964824/azureml-logs/azureml.log?sv=2017-04-17&sr=b&sig=Kw8jDibDdJTOqZhGdk1q0d61PVdWF%2B%2FDwOZHq5GbOqc%3D&st=2018-10-08T11%3A34%3A10Z&se=2018-10-08T19%3A44%3A10Z&sp=r',
#   'azureml-logs/55_batchai_execution.txt': 'https://legovision1529597820.blob.core.windows.net/azureml/ExperimentRun/naive-bayes-classifier_1538996964824/azureml-logs/55_batchai_execution.txt?sv=2017-04-17&sr=b&sig=olTEX3lZsXrMg71iZTQZLtWHQ6%2BZrpceMeqJlEUkMiQ%3D&st=2018-10-08T11%3A34%3A10Z&se=2018-10-08T19%3A44%3A10Z&sp=r'}}

# %%
print(run.get_metrics())

# %%
from sklearn.model_selection import train_test_split
import numpy as np

X = np.array(X)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

classifiers = [GaussianNB(), BernoulliNB(), MultinomialNB()]

# %%
from sklearn.metrics import classification_report,accuracy_score

for classifier in classifiers:    
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)   
    print(f"Classifier: {classifier.__class__}")
    print("Accuracy: "+str(accuracy_score(y_test, y_pred)))
    print('\n')
    print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-655051d03024> in <module>()
#       2
#       3 for classifier in classifiers:
# ----> 4     classifier.fit(X_train, y_train)
#       5     y_pred = classifier.predict(X_test)
#       6     print(f"Classifier: {classifier.__class__}")
#
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     181             Returns self.
#     182         """
# --> 183         X, y = check_X_y(X, y)
#     184         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     185                                  sample_weight=sample_weight)
#
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# c:\users\thijs\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
